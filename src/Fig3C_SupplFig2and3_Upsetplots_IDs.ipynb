# %% [markdown]
# ### Upsetplots for Identifications per confidence type

# %% [markdown]
# Tier 1, canonical: 19722
# Tier 2, indistinguishable representative: 3382
# Tier 6, insufficient evidence: 302
# Tier 4, marginally distinguished: 4456
# Tier 1, canonical: 1832
# Tier 3, representative: 0
# Tier 8, subsumed: 10557
# Tier 5, weak: 2067
#
#
# Presence levels:
# 1. Identical
# 2. Indistinguishable

# %%
import pandas as pd
from pathlib import Path
from upsetplot import plot, UpSet, from_contents
import warnings
import matplotlib.pyplot as plt

# %%
# filter FutureWarnings from pandas, otherwise notebook gets crowded
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
folder = "../../../data/atlas_data/per_evidence_level"
files = Path(folder).glob("*.tsv")

IDs = {}

for file in files:
    name = file.name
    name = name.replace(".tsv", "").replace("PA2_", "")
    IDs[name] = pd.read_table(file)
    # filter out phages
    IDs[name] = IDs[name][~IDs[name]["biosequence_name"].str.contains("PHAGE_sp")]

IDs["uncertain"] = pd.concat([IDs["weak"], IDs["insufficient_evidence"], IDs["subsumed"], IDs["indistinguishable_representative"]])
del IDs["insufficient_evidence"]
del IDs["subsumed"]
del IDs["indistinguishable_representative"]
del IDs["weak"]

IDs["canonical"] = pd.concat([IDs["canonical"], IDs["noncore_canonical"]])
del IDs["noncore_canonical"]

IDs["indistinguishable_from_canonical"] = IDs["canonical"][IDs["canonical"]["relationship_phrase"] == "indistinguishable"]
IDs["canonical"] = IDs["canonical"][IDs["canonical"]["relationship_phrase"] != "indistinguishable"]

IDs["uncertain"] = pd.concat([IDs["uncertain"], IDs["marginally_distinguished"][IDs["marginally_distinguished"]["relationship_phrase"] == "indistinguishable"]])
IDs["marginally_distinguished"] = IDs["marginally_distinguished"][IDs["marginally_distinguished"]["relationship_phrase"] != "indistinguishable"]

IDs["indistinguishable_from_canonical"]["presence_level"] = "indistinguishable_from_canonical"
IDs["canonical"]["presence_level"] = "canonical"
IDs["marginally_distinguished"]["presence_level"] = "marginally_distinguished"
IDs["uncertain"]["presence_level"] = "uncertain"

del IDs["all_tiers"]

for key in IDs:
    print(f'{key}: {len(IDs[key])}')

presence_levels = pd.concat([IDs["canonical"], IDs["indistinguishable_from_canonical"], IDs["marginally_distinguished"], IDs["uncertain"]])

# to dict
presence_levels = presence_levels.drop(columns=["relationship_phrase"])
presence_dict = pd.Series(presence_levels.presence_level.values,index=presence_levels.biosequence_name).to_dict()
# Out:
# canonical: 19171
# marginally_distinguished: 4207
# uncertain: 16272
# indistinguishable_from_canonical: 2409

# %%
presence_dict
# Out:
# {'A5A614': 'canonical',
#  'A0A140NCC8': 'canonical',
#  'B7UR93': 'canonical',
#  'ECFI10_01282': 'canonical',
#  'ECFI19_01248': 'canonical',
#  'ECFI4_01175': 'canonical',
#  'UPI00000DEB2C': 'canonical',
#  'P00350': 'canonical',
#  'UPI0000124F6D': 'canonical',
#  'P00363': 'canonical',
#  'A0A140NCT2': 'canonical',
#  'D6IH97': 'canonical',
#  'ECFI10_04132': 'canonical',
#  'ECFI19_04131': 'canonical',
#  'UPI000011214D': 'canonical',
#  'P00370': 'canonical',
#  'A0A140NBC5': 'canonical',
#  'ECFI10_01731': 'canonical',
#  'ECFI19_01723': 'canonical',
#  'UPI00001292FA': 'canonical',
#  'P00393': 'canonical',
#  'D6I639': 'canonical',
#  'UPI000011DD2D': 'canonical',
#  'P00448': 'canonical',
#  'ECFI19_03849': 'canonical',
#  'UPI0000168202': 'canonical',
#  'P00452': 'canonical',
#  'A0A140N9Q4': 'canonical',
#  'ECFI10_02213': 'canonical',
#  'UPI0000112BE0': 'canonical',
#  'P00490': 'canonical',
#  'P0AC86': 'canonical',
#  'A0A140N753': 'canonical',
#  'UPI000016F62C': 'canonical',
#  'A0A140N6M9': 'canonical',
#  'ECFI10_03340': 'canonical',
#  'ECFI19_03350': 'canonical',
#  'UPI0000131A13': 'canonical',
#  'P00509': 'canonical',
#  'P04693': 'canonical',
#  'A0A140ND68': 'canonical',
#  'D6I8J7': 'canonical',
#  'ECFI10_00931': 'canonical',
#  'ECFI19_00905': 'canonical',
#  'UPI000011044B': 'canonical',
#  'UPI0000112D7A': 'canonical',
#  'P00547': 'canonical',
#  'UPI000012DE19': 'canonical',
#  'P00550': 'canonical',
#  'A0A140N201': 'canonical',
#  'ECFI10_03530': 'canonical',
#  'ECFI19_03542': 'canonical',
#  'UPI0000132958': 'canonical',
#  'P00561': 'canonical',
#  'B7UI47': 'canonical',
#  'D6IHW3': 'canonical',
#  'UPI000015C836': 'canonical',
#  'P00562': 'canonical',
#  'ECFI19_03884': 'canonical',
#  'UPI0000168207': 'canonical',
#  'P00579': 'canonical',
#  'P0AGB3': 'canonical',
#  'P13445': 'canonical',
#  'P16431': 'canonical',
#  'B7UHD6': 'canonical',
#  'ECFI20_02594': 'canonical',
#  'ECFI4_02436': 'canonical',
#  'UPI00000D5E03': 'canonical',
#  'UPI0000134827': 'canonical',
#  'A0A0H2Z4I2': 'canonical',
#  'A0A140N4P1': 'canonical',
#  'B7UL12': 'canonical',
#  'D6IEZ6': 'canonical',
#  'ECFI10_03373': 'canonical',
#  'ECFI19_03384': 'canonical',
#  'ECFI20_03309': 'canonical',
#  'ECFI4_03130': 'canonical',
#  'UPI0000134562': 'canonical',
#  'UPI00000017FA': 'canonical',
#  'A0A140N8Z0': 'canonical',
#  'ECFI10_02651': 'canonical',
#  'ECFI19_02633': 'canonical',
#  'UPI000012CFE2': 'canonical',
#  'P00582': 'canonical',
#  'P25549': 'canonical',
#  'A0A140NER9': 'canonical',
#  'ECFI10_03788': 'canonical',
#  'UPI0000129763': 'canonical',
#  'UPI0000126109': 'canonical',
#  'P00634': 'canonical',
#  'UPI0000132009': 'canonical',
#  'P00803': 'canonical',
#  'ECFI19_02507': 'canonical',
#  'UPI0000047C57': 'canonical',
#  'P00804': 'canonical',
#  'ECFI10_00027': 'canonical',
#  'B7UI72': 'canonical',
#  'D6IHY7': 'canonical',
#  'ECFI4_00025': 'canonical',
#  'UPI00000DE6D7': 'canonical',
#  'ECFI19_00027': 'canonical',
#  'UPI000012E974': 'canonical',
#  'P00805': 'canonical',
#  'A0A140N7Y9': 'canonical',
#  'UPI00001260FB': 'canonical',
#  'P00811': 'canonical',
#  'UPI00001259D7': 'canonical',
#  'P00816': 'canonical',
#  'A0A140NAG6': 'canonical',
#  'ECFI10_00331': 'canonical',
#  'UPI0000128C3E': 'canonical',
#  'P00861': 'canonical',
#  'A0A140N6V2': 'canonical',
#  'ECFI10_02768': 'canonical',
#  'UPI0000128F68': 'canonical',
#  'P00864': 'canonical',
#  'B7UNT2': 'canonical',
#  'UPI000003EB5B': 'canonical',
#  'P00893': 'canonical',
#  'ECFI19_00080': 'canonical',
#  'UPI000012D5BB': 'canonical',
#  'P00894': 'canonical',
#  'A0A140NB40': 'canonical',
#  'ECFI10_00083': 'canonical',
#  'ECFI19_00081': 'canonical',
#  'UPI0000167FFE': 'canonical',
#  'P00895': 'canonical',
#  'ECFI10_01257': 'canonical',
#  'UPI00001375B8': 'canonical',
#  'P00903': 'canonical',
#  'A0A140N6U8': 'canonical',
#  'D6IEP6': 'canonical',
#  'ECFI10_03273': 'canonical',
#  'ECFI19_03284': 'canonical',
#  'UPI00001311AF': 'canonical',
#  'P00904': 'canonical',
#  'A0A140NCY2': 'canonical',
#  'ECFI10_01256': 'canonical',
#  'ECFI19_01224': 'canonical',
#  'UPI000016808C': 'canonical',
#  'P00909': 'canonical',
#  'P75874': 'canonical',
#  'UPI000016808B': 'canonical',
#  'ECFI10_00969': 'canonical',
#  'UPI000013A5CB': 'canonical',
#  'P00914': 'canonical',
#  'ECFI19_00669': 'canonical',
#  'UPI00001319F3': 'canonical',
#  'P00926': 'canonical',
#  'UPI000013572A': 'canonical',
#  'P00934': 'canonical',
#  'UPI0000136ED3': 'canonical',
#  'P00935': 'canonical',
#  'ECFI10_03879': 'canonical',
#  'ECFI19_03883': 'canonical',
#  'UPI000012EF5D': 'canonical',
#  'P00936': 'canonical',
#  'ECFI19_03743': 'canonical',
#  'UPI00001681EF': 'canonical',
#  'P00944': 'canonical',
#  'UPI0000139034': 'canonical',
#  'P00946': 'canonical',
#  'UPI000003EB16': 'canonical',
#  'P00954': 'canonical',
#  'A0A140N7C1': 'canonical',
#  'ECFI10_03297': 'canonical',
#  'ECFI19_03307': 'canonical',
#  'UPI00001681B2': 'canonical',
#  'P00956': 'canonical',
#  'ECFI19_00026': 'canonical',
#  'UPI0000167FF6': 'canonical',
#  'P00957': 'canonical',
#  'ECFI10_02627': 'canonical',
#  'UPI0000136304': 'canonical',
#  'P00959': 'canonical',
#  'UPI000016810B': 'canonical',
#  'P00960': 'canonical',
#  'UPI0000136477': 'canonical',
#  'P00961': 'canonical',
#  'A0A140N2U8': 'canonical',
#  'ECFI19_03496': 'canonical',
#  'UPI00001681D5': 'canonical',
#  'P00962': 'canonical',
#  'A0A140NAB7': 'canonical',
#  'ECFI10_00668': 'canonical',
#  'ECFI19_00644': 'canonical',
#  'UPI0000168044': 'canonical',
#  'P00963': 'canonical',
#  'ECFI19_03680': 'canonical',
#  'UPI0000126116': 'canonical',
#  'P00968': 'canonical',
#  'UPI0000110AAB': 'canonical',
#  'P02358': 'canonical',
#  'P02359': 'canonical',
#  'UPI0000047C5A': 'canonical',
#  'P02413': 'canonical',
#  'P75981': 'canonical',
#  'ECFI19_03223': 'canonical',
#  'UPI000003EAC3': 'canonical',
#  'UPI000013B9BA': 'canonical',
#  'P02916': 'canonical',
#  'A0A140NEB1': 'canonical',
#  'ECFI10_03982': 'canonical',
#  'ECFI19_03983': 'canonical',
#  'UPI000012EB4A': 'canonical',
#  'P02918': 'canonical',
#  'ECFI19_03319': 'canonical',
#  'UPI0000131398': 'canonical',
#  'P02919': 'canonical',
#  'UPI0000168005': 'canonical',
#  'P02920': 'canonical',
#  'A0A0H2YW99': 'canonical',
#  'A0A140ND47': 'canonical',
#  'B7UJI8': 'canonical',
#  'D6I6F4': 'canonical',
#  'ECFI10_00334': 'canonical',
#  'ECFI19_00310': 'canonical',
#  'ECFI4_00305': 'canonical',
#  'UPI000011F071': 'canonical',
#  'P02921': 'canonical',
#  'ECFI10_04094': 'canonical',
#  'UPI0001FB79C0': 'canonical',
#  'P02924': 'canonical',
#  'A0A140NAP3': 'canonical',
#  'ECFI10_01877': 'canonical',
#  'ECFI19_01872': 'canonical',
#  'UPI0000125D6C': 'canonical',
#  'P02925': 'canonical',
#  'UPI000003EB7E': 'canonical',
#  'P02929': 'canonical',
#  'UPI000013711A': 'canonical',
#  'P02930': 'canonical',
#  'A0A140N6A8': 'canonical',
#  'D6IDW3': 'canonical',
#  'ECFI10_02953': 'canonical',
#  'ECFI19_02945': 'canonical',
#  'UPI0000683E8B': 'canonical',
#  'P02943': 'canonical',
#  'A0A140NEY2': 'canonical',
#  'ECFI19_03988': 'canonical',
#  'UPI000012E213': 'canonical',
#  'P03004': 'canonical',
#  'A0A140N2D9': 'canonical',
#  'B7UMG9': 'canonical',
#  'D6IFU6': 'canonical',
#  'ECFI10_03629': 'canonical',
#  'ECFI19_03637': 'canonical',
#  'ECFI20_03553': 'canonical',
#  'ECFI4_03355': 'canonical',
#  'UPI0000129521': 'canonical',
#  'P03007': 'canonical',
#  'UPI0000129714': 'canonical',
#  'P03014': 'canonical',
#  'UPI0000131AF4': 'canonical',
#  'P03018': 'canonical',
#  'A0A140NHJ4': 'canonical',
#  'B7UND0': 'canonical',
#  'ECFI10_03739': 'canonical',
#  'ECFI4_03467': 'canonical',
#  'UPI00000D08F3': 'canonical',
#  'UPI0000137EFA': 'canonical',
#  'P03023': 'canonical',
#  'UPI000011D868': 'canonical',
#  'P03024': 'canonical',
#  'ECFI19_02748': 'canonical',
#  'UPI000012B0AC': 'canonical',
#  'P03030': 'canonical',
#  'UPI000012EAA3': 'canonical',
#  'P03813': 'canonical',
#  'UPI000013B061': 'canonical',
#  'P03817': 'canonical',
#  'UPI000003EB7A': 'canonical',
#  'P03819': 'canonical',
#  'ECFI10_00049': 'canonical',
#  'ECFI19_00048': 'canonical',
#  'ECFI20_00053': 'canonical',
#  'UPI000187B808': 'canonical',
#  'UPI00000DE6E3': 'canonical',
#  'UPI000012DD92': 'canonical',
#  'P03835': 'canonical',
#  'A0A140NCI0': 'canonical',
#  'UPI0000000402': 'canonical',
#  'P03841': 'canonical',
#  'A0A140NFH4': 'canonical',
#  'ECFI19_03989': 'canonical',
#  'UPI000012EB56': 'canonical',
#  'P03959': 'canonical',
#  'ECFI10_00684': 'canonical',
#  'UPI00000DE897': 'canonical',
#  'UPI000012625C': 'canonical',
#  'P03960': 'canonical',
#  'P37595': 'canonical',
#  'P39199': 'canonical',
#  'UPI000012626A': 'canonical',
#  'UPI00001260FE': 'canonical',
#  'UPI000013ADF9': 'canonical',
#  'P03961': 'canonical',
#  'UPI0000126280': 'canonical',
#  'P04036': 'canonical',
#  'ECFI19_00031': 'canonical',
#  'UPI0000110629': 'canonical',
#  'P04079': 'canonical',
#  'P60595': 'canonical',
#  'A0A140N9Q3': 'canonical',
#  'D6IAD6': 'canonical',
#  'ECFI10_02460': 'canonical',
#  'ECFI19_02437': 'canonical',
#  'UPI00001119A3': 'canonical',
#  'A0A0H2Z0A8': 'canonical',
#  'B7UT60': 'canonical',
#  'D6I993': 'canonical',
#  'ECFI4_01815': 'canonical',
#  'UPI000012C7F9': 'canonical',
#  'P04128': 'canonical',
#  'A0A140NE71': 'canonical',
#  'UPI0000047611': 'canonical',
#  'P04152': 'canonical',
#  'A0A140NAT3': 'canonical',
#  'ECFI10_01165': 'canonical',
#  'ECFI19_01137': 'canonical',
#  'UPI0000137C33': 'canonical',
#  'P04335': 'canonical',
#  'D6I674': 'canonical',
#  'UPI000013A07B': 'canonical',
#  'P04391': 'canonical',
#  'P06960': 'canonical',
#  'UPI0000168235': 'canonical',
#  'UPI000016801A': 'canonical',
#  'P04395': 'canonical',
#  'UPI0000124EE5': 'canonical',
#  'P04425': 'canonical',
#  'A0A140N801': 'canonical',
#  'ECFI19_02856': 'canonical',
#  'UPI00000480C1': 'canonical',
#  'P04805': 'canonical',
#  'A0A140N9E5': 'canonical',
#  'ECFI10_02358': 'canonical',
#  'ECFI19_02329': 'canonical',
#  'UPI00001363DF': 'canonical',
#  'P04825': 'canonical',
#  'A0A140NDT0': 'canonical',
#  'ECFI10_00935': 'canonical',
#  'ECFI19_00909': 'canonical',
#  'UPI0000168063': 'canonical',
#  'P04846': 'canonical',
#  'UPI000013021B': 'canonical',
#  'P04951': 'canonical',
#  'A0A140ND77': 'canonical',
#  'ECFI10_00920': 'canonical',
#  'ECFI19_00894': 'canonical',
#  'UPI0000168061': 'canonical',
#  'P04968': 'canonical',
#  'UPI0000112D97': 'canonical',
#  'P04982': 'canonical',
#  'UPI0000165534': 'canonical',
#  'P04993': 'canonical',
#  'ECFI19_02727': 'canonical',
#  'UPI000012A2CB': 'canonical',
#  'P04994': 'canonical',
#  'A0A140N7P0': 'canonical',
#  'ECFI10_02462': 'canonical',
#  'ECFI19_02439': 'canonical',
#  'UPI000012A2E6': 'canonical',
#  'P04995': 'canonical',
#  'UPI000012A2BA': 'canonical',
#  'P05020': 'canonical',
#  'UPI0000168075': 'canonical',
#  'P05041': 'canonical',
#  'UPI000011323C': 'canonical',
#  'P05042': 'canonical',
#  'D6IAS3': 'canonical',
#  'ECFI10_01571': 'canonical',
#  'UPI00001117A0': 'canonical',
#  'P05052': 'canonical',
#  'ECFI19_00531': 'canonical',
#  'UPI0000125CB2': 'canonical',
#  'P05055': 'canonical',
#  'A0A140N5F4': 'canonical',
#  'ECFI10_03070': 'canonical',
#  'ECFI19_03077': 'canonical',
#  'UPI0000131D5A': 'canonical',
#  'P05100': 'canonical',
#  'ECFI10_03472': 'canonical',
#  'UPI0000124EE4': 'canonical',
#  'P05194': 'canonical',
#  'ECFI20_01602': 'canonical',
#  'UPI0000125FC0': 'canonical',
#  'P05458': 'canonical',
#  'ECFI19_02729': 'canonical',
#  'UPI00001329B7': 'canonical',
#  'P05459': 'canonical',
#  'P13518': 'canonical',
#  'UPI0000131505': 'canonical',
#  'A0A140N5F5': 'canonical',
#  'ECFI10_03161': 'canonical',
#  'ECFI19_03172': 'canonical',
#  'UPI000013B1EB': 'canonical',
#  'P05523': 'canonical',
#  'A0A140N6H0': 'canonical',
#  'ECFI10_03560': 'canonical',
#  'ECFI19_03570': 'canonical',
#  'UPI0000043B82': 'canonical',
#  'P05637': 'canonical',
#  'A0A140NGB8': 'canonical',
#  'ECFI10_00051': 'canonical',
#  'ECFI19_00050': 'canonical',
#  'UPI0000125BF9': 'canonical',
#  'P05706': 'canonical',
#  'ECFI19_02616': 'canonical',
#  'UPI00001328E1': 'canonical',
#  'P05707': 'canonical',
#  'D6ICD8': 'canonical',
#  'ECFI19_02617': 'canonical',
#  'UPI0000135F4C': 'canonical',
#  'P05719': 'canonical',
#  'UPI00001367A6': 'canonical',
#  'P05791': 'canonical',
#  'UPI000012D579': 'canonical',
#  'P05793': 'canonical',
#  'P25740': 'canonical',
#  'P25742': 'canonical',
#  'A0A140NI72': 'canonical',
#  'ECFI10_03697': 'canonical',
#  'ECFI19_03709': 'canonical',
#  'UPI00001681EC': 'canonical',
#  'UPI00001337B1': 'canonical',
#  'UPI00001337BD': 'canonical',
#  'P05804': 'canonical',
#  'UPI000011F125': 'canonical',
#  'P05824': 'canonical',
#  'ECFI19_02556': 'canonical',
#  'UPI000013358B': 'canonical',
#  'P05825': 'canonical',
#  'P08244': 'canonical',
#  'P37617': 'canonical',
#  'UPI000012A647': 'canonical',
#  'UPI0000111310': 'canonical',
#  'A0A140N448': 'canonical',
#  'ECFI19_03392': 'canonical',
#  'UPI00000480D2': 'canonical',
#  'P05827': 'canonical',
#  'A0A140NFQ3': 'canonical',
#  'ECFI10_03696': 'canonical',
#  'UPI000012D5C0': 'canonical',
#  'P05847': 'canonical',
#  'A0A140N7N7': 'canonical',
#  'ECFI10_02982': 'canonical',
#  'ECFI19_02975': 'canonical',
#  'UPI000016818B': 'canonical',
#  'P05852': 'canonical',
#  'A0A140N5Q1': 'canonical',
#  'D6IDY6': 'canonical',
#  'ECFI19_02978': 'canonical',
#  'UPI000016818C': 'canonical',
#  'P06129': 'canonical',
#  'ECFI10_03908': 'canonical',
#  'ECFI19_03911': 'canonical',
#  'UPI0000126B1B': 'canonical',
#  'P06134': 'canonical',
#  'UPI00001254EB': 'canonical',
#  'P06136': 'canonical',
#  'P0AEN8': 'canonical',
#  'UPI000012ACEB': 'canonical',
#  'A0A140N901': 'canonical',
#  'A1AEZ1': 'canonical',
#  'B7UHM0': 'canonical',
#  'D6ICN5': 'canonical',
#  'ECFI10_02729': 'canonical',
#  'ECFI19_02711': 'canonical',
#  'ECFI20_02673': 'canonical',
#  'ECFI4_02510': 'canonical',
#  'UPI000012AD59': 'canonical',
#  'P06149': 'canonical',
#  'A0A140NAN1': 'canonical',
#  'ECFI10_02103': 'canonical',
#  'UPI00001114B6': 'canonical',
#  'P06282': 'canonical',
#  'UPI000012741A': 'canonical',
#  'P06610': 'canonical',
#  'A0A140NB95': 'canonical',
#  'ECFI10_01677': 'canonical',
#  'UPI0000126B24': 'canonical',
#  'P06611': 'canonical',
#  'UPI0000126B22': 'canonical',
#  'P06612': 'canonical',
#  'P25906': 'canonical',
#  'A0A140NCX5': 'canonical',
#  'ECFI10_01267': 'canonical',
#  'ECFI19_01235': 'canonical',
#  'UPI0000137136': 'canonical',
#  'ECFI19_01368': 'canonical',
#  'UPI000013A909': 'canonical',
#  'P06709': 'canonical',
#  'UPI00001108FE': 'canonical',
#  'P06710': 'canonical',
#  'A0A140NCN5': 'canonical',
#  'ECFI10_00467': 'canonical',
#  'UPI000012971C': 'canonical',
#  'P06715': 'canonical',
#  'UPI0000047CBF': 'canonical',
#  'P06720': 'canonical',
#  'ECFI19_04092': 'canonical',
#  'UPI00001256AA': 'canonical',
#  'P06721': 'canonical',
#  'ECFI19_02919': 'canonical',
#  'UPI0000110CEA': 'canonical',
#  'P06722': 'canonical',
#  'A0A140N8M6': 'canonical',
#  'ECFI10_02759': 'canonical',
#  'ECFI19_02740': 'canonical',
#  'UPI0000168166': 'canonical',
#  'P06864': 'canonical',
#  'UPI00003B25F9': 'canonical',
#  'P06959': 'canonical',
#  'P0AC41': 'canonical',
#  'D6I6U2': 'canonical',
#  'A0A140NE27': 'canonical',
#  'D6II74': 'canonical',
#  'ECFI10_00122': 'canonical',
#  'UPI00000480B8': 'canonical',
#  'A0A140NA80': 'canonical',
#  'ECFI10_00711': 'canonical',
#  'ECFI19_00686': 'canonical',
#  'ECFI4_00642': 'canonical',
#  'UPI00001127A5': 'canonical',
#  'P06961': 'canonical',
#  'A0A140N5Y3': 'canonical',
#  'ECFI10_02976': 'canonical',
#  'ECFI19_02969': 'canonical',
#  'UPI0000127286': 'canonical',
#  'P06965': 'canonical',
#  'UPI00001293D0': 'canonical',
#  'P06966': 'canonical',
#  'UPI00001293CE': 'canonical',
#  'P06968': 'canonical',
#  'UPI00001110EB': 'canonical',
#  'P06971': 'canonical',
#  'UPI000012A73E': 'canonical',
#  'P06974': 'canonical',
#  'A0A140N6S3': 'canonical',
#  'UPI000012A9CF': 'canonical',
#  'P06986': 'canonical',
#  'UPI00001118C8': 'canonical',
#  'P06987': 'canonical',
#  'UPI000012C855': 'canonical',
#  'P06988': 'canonical',
#  'UPI0000168100': 'canonical',
#  'P06989': 'canonical',
#  'A0A0H2Z0B1': 'canonical',
#  'A0A140NAD1': 'canonical',
#  'UPI000012C773': 'canonical',
#  'P06992': 'canonical',
#  'A0A140NE88': 'canonical',
#  'D6II14': 'canonical',
#  'ECFI10_00053': 'canonical',
#  'ECFI19_00052': 'canonical',
#  'UPI000012E09F': 'canonical',
#  'P06993': 'canonical',
#  'ECFI19_03341': 'canonical',
#  'UPI00001681BA': 'canonical',
#  'P02931': 'canonical',
#  'P02932': 'canonical',
#  'P06996': 'canonical',
#  'P21420': 'canonical',
#  'P67080': 'canonical',
#  'P76335': 'canonical',
#  'P76463': 'canonical',
#  'P77747': 'canonical',
#  'A0A140NAN5': 'canonical',
#  'ECFI10_00932': 'canonical',
#  'UPI0000032AA9': 'canonical',
#  'UPI00001319BB': 'canonical',
#  'ECFI10_02192': 'canonical',
#  'UPI0000032AA8': 'canonical',
#  'UPI00001B3DED': 'canonical',
#  'A0A140N3P1': 'canonical',
#  'B7UHZ8': 'canonical',
#  'D6ID46': 'canonical',
#  'ECFI19_02860': 'canonical',
#  'ECFI4_02642': 'canonical',
#  'UPI000013B09D': 'canonical',
#  'UPI00001B511B': 'canonical',
#  'A0A140N7U2': 'canonical',
#  'ECFI19_02172': 'canonical',
#  'UPI000013ADC4': 'canonical',
#  'UPI0000130D13': 'canonical',
#  'P06999': 'canonical',
#  'A0A140NB59': 'canonical',
#  'ECFI10_01692': 'canonical',
#  'UPI000012DB3D': 'canonical',
#  'P07000': 'canonical',
#  'ECFI20_03680': 'canonical',
#  'A0A140NI27': 'canonical',
#  'D6IG61': 'canonical',
#  'ECFI10_03749': 'canonical',
#  'ECFI4_03476': 'canonical',
#  'UPI000000E972': 'canonical',
#  'P07001': 'canonical',
#  'ECFI10_01563': 'canonical',
#  'ECFI4_01397': 'canonical',
#  'UPI0000DACE55': 'canonical',
#  'ECFI19_01553': 'canonical',
#  'UPI0000131D61': 'canonical',
#  'P07003': 'canonical',
#  'UPI000004CE7A': 'canonical',
#  'P07004': 'canonical',
#  'ECFI19_00250': 'canonical',
#  'UPI000003EB08': 'canonical',
#  'P07012': 'canonical',
#  'UPI000003EB03': 'canonical',
#  'P07013': 'canonical',
#  'A0A140NGL6': 'canonical',
#  'B7UQL0': 'canonical',
#  'D6IHD9': 'canonical',
#  'ECFI10_04178': 'canonical',
#  'ECFI19_04179': 'canonical',
#  'ECFI20_04078': 'canonical',
#  'ECFI4_03872': 'canonical',
#  'UPI00000D0367': 'canonical',
#  'UPI0000168229': 'canonical',
#  'P07014': 'canonical',
#  'UPI00001127A6': 'canonical',
#  'P02942': 'canonical',
#  'P05704': 'canonical',
#  'P07017': 'canonical',
#  'P07018': 'canonical',
#  'P50466': 'canonical',
#  'UPI000012EDA2': 'canonical',
#  'A0A140NBY7': 'canonical',
#  'ECFI10_01400': 'canonical',
#  'UPI000012EDA5': 'canonical',
#  'A0A140N971': 'canonical',
#  'D6IBJ7': 'canonical',
#  'ECFI10_01862': 'canonical',
#  'UPI000012EDA3': 'canonical',
#  'ECFI19_01856': 'canonical',
#  'UPI000012EDA6': 'canonical',
#  'A0A140N7M8': 'canonical',
#  'ECFI10_02993': 'canonical',
#  'ECFI19_02986': 'canonical',
#  'UPI0000125646': 'canonical',
#  'P07021': 'canonical',
#  'D6IC60': 'canonical',
#  'ECFI10_02568': 'canonical',
#  'ECFI19_02546': 'canonical',
#  'UPI000013AEA8': 'canonical',
#  'P07023': 'canonical',
#  'ECFI19_02541': 'canonical',
#  'UPI0000046F13': 'canonical',
#  'P07024': 'canonical',
#  'A0A140NCM7': 'canonical',
#  'ECFI10_00479': 'canonical',
#  'ECFI19_00455': 'canonical',
#  'UPI0000112E87': 'canonical',
#  'P07026': 'canonical',
#  'A0A140N639': 'canonical',
#  'UPI0000135739': 'canonical',
#  'P07102': 'canonical',
#  'ECFI19_00953': 'canonical',
#  'UPI000004750A': 'canonical',
#  'P07117': 'canonical',
#  'ECFI10_01022': 'canonical',
#  'UPI0000132B86': 'canonical',
#  'P07118': 'canonical',
#  'P0AFF2': 'canonical',
#  'P25798': 'canonical',
#  'UPI00001366F5': 'canonical',
#  'A0A0H2Z1T9': 'canonical',
#  'A0A140NA02': 'canonical',
#  'B7UGA1': 'canonical',
#  'D6IA37': 'canonical',
#  'ECFI10_02350': 'canonical',
#  'ECFI19_02321': 'canonical',
#  'ECFI20_02309': 'canonical',
#  'ECFI4_02163': 'canonical',
#  'UPI0000130A2E': 'canonical',
#  'A0A140NAJ3': 'canonical',
#  'UPI000012A9A6': 'canonical',
#  'P07330': 'canonical',
#  'UPI00001277A2': 'canonical',
#  'P07364': 'canonical',
#  'ECFI20_01798': 'canonical',
#  'UPI0000DACE97': 'canonical',
#  'ECFI19_01855': 'canonical',
#  'UPI00001277B3': 'canonical',
#  'P07395': 'canonical',
#  'A0A140N8N4': 'canonical',
#  'ECFI10_01681': 'canonical',
#  'ECFI19_01672': 'canonical',
#  'UPI0000136447': 'canonical',
#  'P07464': 'canonical',
#  'ECFI10_00333': 'canonical',
#  'UPI0000112228': 'canonical',
#  'P07604': 'canonical',
#  'A0A140NC83': 'canonical',
#  'ECFI10_01320': 'canonical',
#  'ECFI19_01287': 'canonical',
#  'UPI00001378B7': 'canonical',
#  'P07623': 'canonical',
#  'UPI00001588E1': 'canonical',
#  'P07648': 'canonical',
#  'D6ICQ0': 'canonical',
#  'UPI000012A2D4': 'canonical',
#  'P07649': 'canonical',
#  'UPI000013766E': 'canonical',
#  'P07650': 'canonical',
#  'UPI000011DB05': 'canonical',
#  'P07654': 'canonical',
#  'ECFI19_03661': 'canonical',
#  'UPI000003EB1B': 'canonical',
#  'P07658': 'canonical',
#  'B7UPQ2': 'canonical',
#  'UPI0000168218': 'canonical',
#  'P07762': 'canonical',
#  'A0A140N767': 'canonical',
#  'ECFI10_03344': 'canonical',
#  'ECFI19_03354': 'canonical',
#  'UPI000012B5AD': 'canonical',
#  'P07813': 'canonical',
#  'UPI000013655E': 'canonical',
#  'P07821': 'canonical',
#  'ECFI19_00149': 'canonical',
#  'UPI000012A741': 'canonical',
#  'P07822': 'canonical',
#  'UPI000012A742': 'canonical',
#  'P07862': 'canonical',
#  'D6II53': 'canonical',
#  'UPI000003EB68': 'canonical',
#  'P07913': 'canonical',
#  'UPI0000136B52': 'canonical',
#  'P08142': 'canonical',
#  'A0A140N2H0': 'canonical',
#  'ECFI10_03597': 'canonical',
#  'UPI000003EB0D': 'canonical',
#  'P08178': 'canonical',
#  'UPI000016813C': 'canonical',
#  'P08179': 'canonical',
#  'UPI0000110B1A': 'canonical',
#  'P08189': 'canonical',
#  'ECFI20_04153': 'canonical',
#  'ECFI4_03961': 'canonical',
#  'UPI00000B2D8B': 'canonical',
#  'A0A140NGB0': 'canonical',
#  'UPI0000047CAF': 'canonical',
#  'P08190': 'canonical',
#  'ECFI20_04154': 'canonical',
#  'ECFI4_03962': 'canonical',
#  'UPI00000D0D31': 'canonical',
#  'A0A140NG62': 'canonical',
#  'UPI0000047CB0': 'canonical',
#  'P08191': 'canonical',
#  'ECFI19_04273': 'canonical',
#  'UPI0000047CB1': 'canonical',
#  'P08192': 'canonical',
#  'A0A140N539': 'canonical',
#  'ECFI10_02293': 'canonical',
#  'ECFI19_02262': 'canonical',
#  'UPI000012AB4B': 'canonical',
#  'P08194': 'canonical',
#  'UPI000012B7B5': 'canonical',
#  'P08200': 'canonical',
#  'UPI000011050D': 'canonical',
#  'P08201': 'canonical',
#  'A0A140N552': 'canonical',
#  'ECFI10_03278': 'canonical',
#  'ECFI19_03289': 'canonical',
#  'UPI00001301A7': 'canonical',
#  'P08202': 'canonical',
#  'UPI0000167FF9': 'canonical',
#  'P08204': 'canonical',
#  'UPI0000167FFA': 'canonical',
#  'P08245': 'canonical',
#  'A0A140NAI2': 'canonical',
#  'ECFI10_01279': 'canonical',
#  'ECFI19_01245': 'canonical',
#  'UPI000013A6BE': 'canonical',
#  'P08312': 'canonical',
#  'A0A140N6N0': 'canonical',
#  'ECFI10_01682': 'canonical',
#  'ECFI19_01673': 'canonical',
#  'UPI000013640D': 'canonical',
#  'P08331': 'canonical',
#  'D6IHF2': 'canonical',
#  'ECFI20_04090': 'canonical',
#  'UPI0000127BE1': 'canonical',
#  'P08337': 'canonical',
#  'A0A140NB17': 'canonical',
#  'ECFI10_00105': 'canonical',
#  'UPI00001126EC': 'canonical',
#  'P08365': 'canonical',
#  'ECFI19_04201': 'canonical',
#  'UPI00001278B5': 'canonical',
#  'P08368': 'canonical',
#  'UPI000012841C': 'canonical',
#  'P08369': 'canonical',
#  'UPI0000128422': 'canonical',
#  'P08370': 'canonical',
#  'ECFI19_02732': 'canonical',
#  'UPI000013B04E': 'canonical',
#  'P08371': 'canonical',
#  'P0AFQ5': 'canonical',
#  'ECFI10_02752': 'canonical',
#  'ECFI19_02733': 'canonical',
#  'UPI000013204D': 'canonical',
#  'A1A9R5': 'canonical',
#  'B7UNZ3': 'canonical',
#  'C6EHJ7': 'canonical',
#  'D6I8S6': 'canonical',
#  'ECFI10_01017': 'canonical',
#  'ECFI19_00984': 'canonical',
#  'ECFI20_00987': 'canonical',
#  'ECFI4_00919': 'canonical',
#  'UPI000013A5E1': 'canonical',
#  'P08373': 'canonical',
#  'UPI0000112592': 'canonical',
#  'P08390': 'canonical',
#  'A0A140N849': 'canonical',
#  'D6I9Q9': 'canonical',
#  'ECFI10_02297': 'canonical',
#  'ECFI19_02266': 'canonical',
#  'UPI0000137E50': 'canonical',
#  'P08394': 'canonical',
#  'ECFI10_02747': 'canonical',
#  'UPI000012A2D0': 'canonical',
#  'P08395': 'canonical',
#  'UPI00001680D5': 'canonical',
#  'P08400': 'canonical',
#  'UPI000011F517': 'canonical',
#  'P08401': 'canonical',
#  'ECFI4_04038': 'canonical',
#  'B7UR28': 'canonical',
#  'UPI0000168254': 'canonical',
#  'P08506': 'canonical',
#  'P0ADZ4': 'canonical',
#  'P0AEB2': 'canonical',
#  'P33013': 'canonical',
#  'A0A140NE46': 'canonical',
#  'ECFI10_00836': 'canonical',
#  'ECFI19_00812': 'canonical',
#  'UPI0000128DDA': 'canonical',
#  'A0A140N811': 'canonical',
#  'A1AG70': 'canonical',
#  'B7UJ60': 'canonical',
#  'ECFI10_03072': 'canonical',
#  'ECFI19_03079': 'canonical',
#  'ECFI20_03017': 'canonical',
#  'ECFI4_02838': 'canonical',
#  'UPI0000163A0F': 'canonical',
#  'A0A0H2YWK4': 'canonical',
#  'A0A140NBN8': 'canonical',
#  'B7UKS2': 'canonical',
#  'D6I6M0': 'canonical',
#  'ECFI10_00623': 'canonical',
#  'ECFI19_00607': 'canonical',
#  'ECFI20_00615': 'canonical',
#  'ECFI4_00572': 'canonical',
#  'UPI0000128DD7': 'canonical',
#  'UPI0000128DDB': 'canonical',
#  'P08550': 'canonical',
#  'UPI000012872C': 'canonical',
#  'P08555': 'canonical',
#  'ECFI20_02280': 'canonical',
#  'A0A140N5R1': 'canonical',
#  'ECFI19_02294': 'canonical',
#  'UPI00001298FF': 'canonical',
#  'P08622': 'canonical',
#  'UPI0000167FF5': 'canonical',
#  'P08660': 'canonical',
#  'A0A140NEC0': 'canonical',
#  'ECFI10_03970': 'canonical',
#  'UPI0000033838': 'canonical',
#  'P08839': 'canonical',
#  'P32670': 'canonical',
#  'P77439': 'canonical',
#  'UPI0000132870': 'canonical',
#  'UPI0000132864': 'canonical',
#  'UPI000013BDB2': 'canonical',
#  'P08956': 'canonical',
#  'UPI000199A553': 'canonical',
#  'P08957': 'canonical',
#  'UPI000013678B': 'canonical',
#  'P08997': 'canonical',
#  'UPI000002DB30': 'canonical',
#  'P09029': 'canonical',
#  'UPI0000132B1E': 'canonical',
#  'P09030': 'canonical',
#  'ECFI10_01719': 'canonical',
#  'ECFI19_01711': 'canonical',
#  'UPI0000043B85': 'canonical',
#  'P09053': 'canonical',
#  'UPI00003B2604': 'canonical',
#  'P09099': 'canonical',
#  'UPI0000139056': 'canonical',
#  'P09126': 'canonical',
#  'UPI000012C4A3': 'canonical',
#  'P09127': 'canonical',
#  'UPI000012C5C4': 'canonical',
#  'P09147': 'canonical',
#  'ECFI10_00753': 'canonical',
#  'ECFI19_00728': 'canonical',
#  'UPI0000112E64': 'canonical',
#  'P09148': 'canonical',
#  'ECFI19_00727': 'canonical',
#  'UPI00000480BF': 'canonical',
#  'P09151': 'canonical',
#  'A0A140NFP4': 'canonical',
#  'ECFI10_00079': 'canonical',
#  'ECFI19_00077': 'canonical',
#  'UPI000003B071': 'canonical',
#  'P09152': 'canonical',
#  'P0ADM4': 'canonical',
#  'P19319': 'canonical',
#  'ECFI19_03623': 'canonical',
#  'UPI00005EEB0C': 'canonical',
#  'UPI0000168087': 'canonical',
#  'UPI000013B3B8': 'canonical',
#  'A0A140NCF0': 'canonical',
#  'UPI000003EAFF': 'canonical',
#  'P09153': 'canonical',
#  'P77326': 'canonical',
#  'UPI0000136C5E': 'canonical',
#  'UPI0000136C63': 'canonical',
#  'P09154': 'canonical',
#  'UPI000013B9BD': 'canonical',
#  'P09155': 'canonical',
#  'UPI000013436E': 'canonical',
#  'P09158': 'canonical',
#  'A0A140NAZ8': 'canonical',
#  'ECFI10_00128': 'canonical',
#  'UPI0000168002': 'canonical',
#  'P09162': 'canonical',
#  'B7UPG2': 'canonical',
#  'ECFI4_03665': 'canonical',
#  'UPI00005EF7CA': 'canonical',
#  'UPI0001C22F75': 'canonical',
#  'UPI0000043919': 'canonical',
#  'P09163': 'canonical',
#  'UPI000013B512': 'canonical',
#  'P09169': 'canonical',
#  'UPI0000130D16': 'canonical',
#  'P09184': 'canonical',
#  'ECFI20_01872': 'canonical',
#  'A0A140N7Z3': 'canonical',
#  'ECFI10_01933': 'canonical',
#  'UPI00001680EF': 'canonical',
#  'P09323': 'canonical',
#  'UPI000003EAEC': 'canonical',
#  'P09348': 'canonical',
#  'A0A140NAN9': 'canonical',
#  'ECFI10_01867': 'canonical',
#  'ECFI19_01862': 'canonical',
#  'UPI000012F3D1': 'canonical',
#  'P09372': 'canonical',
#  'UPI000012BB1F': 'canonical',
#  'P09373': 'canonical',
#  'P42632': 'canonical',
#  'P68066': 'canonical',
#  'A0A0H2YXQ6': 'canonical',
#  'A0A140NBE7': 'canonical',
#  'ECFI10_00905': 'canonical',
#  'ECFI19_00879': 'canonical',
#  'ECFI20_00887': 'canonical',
#  'ECFI4_00824': 'canonical',
#  'UPI00000480DD': 'canonical',
#  'A0A140N857': 'canonical',
#  'ECFI10_03035': 'canonical',
#  'ECFI19_03029': 'canonical',
#  'UPI00003B25FE': 'canonical',
#  'A0A140N4H5': 'canonical',
#  'ECFI10_02542': 'canonical',
#  'ECFI19_02519': 'canonical',
#  'UPI000013AEAC': 'canonical',
#  'P09391': 'canonical',
#  'A0A140N5A1': 'canonical',
#  'A1AGU7': 'canonical',
#  'B7UKC8': 'canonical',
#  'ECFI10_03336': 'canonical',
#  'ECFI19_03346': 'canonical',
#  'ECFI4_03092': 'canonical',
#  'UPI00000DF17B': 'canonical',
#  'P09394': 'canonical',
#  'P46859': 'canonical',
#  'ECFI20_03286': 'canonical',
#  'ECFI4_03104': 'canonical',
#  'UPI00016088F2': 'canonical',
#  'UPI000012B7AF': 'canonical',
#  'ECFI10_03348': 'canonical',
#  'ECFI19_03358': 'canonical',
#  'UPI00001121F3': 'canonical',
#  'P09424': 'canonical',
#  'ECFI10_03531': 'canonical',
#  'ECFI19_03543': 'canonical',
#  'ECFI4_03264': 'canonical',
#  'UPI0000191E52': 'canonical',
#  'UPI000012F7E4': 'canonical',
#  'P04949': 'canonical',
#  'P09546': 'canonical',
#  'A0A140NAX2': 'canonical',
#  'UPI00000000AD': 'canonical',
#  'UPI0000132B81': 'canonical',
#  ...}

# %%
strains = ["K12", "MC4100", "BL21", "NC101", "O127H6", "APEC", "ATCC25922", "BW25113", "NCM3722", "W3110", "AB1157", "DH5", "ST73", "ST93", "ST131", "ST1421"]

def parse_clstr_file(filename):

    df = pd.DataFrame(columns=["cluster"] + strains)

    current_cluster = None  # Variable to keep track of the current cluster being processed

    with open(filename, 'r') as file:
        for line in file:
            if line.startswith('>Cluster'):
                current_cluster = line.strip().split(' ')[1]  # Extract the cluster number
                # add row to df
                df = pd.concat([df, pd.DataFrame([[current_cluster] + [0]*len(strains)], columns=["cluster"] + strains)], ignore_index=True)
            else:
                # Extract the strain name from the line
                strain = line.split('>')[1].split('_')[0]

                # Extract the protein ID from the line
                if ">ST" in line:
                    # e.g. >ST73_ECFI4_00021... at 100.00%
                    protein_id = "_".join(line.split('_')[1:3]).split('...')[0]
                elif "|" in line:
                    # e.g. >APEC_sp|A1A7A0|RSMA_ECOK1_00001... at 0.000
                    # or >K12_sp|P0CE51|INSH3_ECOLI
                    protein_id = line.split("|")[1]
                else:
                    # e.g. >ATCC25922_UPI00001363DE... at 0.000
                    protein_id = line.split('_')[1].split('...')[0]

                # set the strain to 1 in df
                df.loc[df["cluster"] == current_cluster, strain] = protein_id

    return df

# %%
def retrieve_highest_evidence_level(row, use_highest_evidence_level=True):
    evidence_levels = set()
    for strain in strains:
        if row[strain] != 0:
            try:
                evidence_levels.add(presence_dict[row[strain]])
            except KeyError:
                evidence_levels.add("not observed")

    if use_highest_evidence_level:
        if "canonical" in evidence_levels:
           return "canonical"
        elif "indistinguishable_from_canonical" in evidence_levels:
            return "indistinguishable from canonical"
        elif "marginally_distinguished" in evidence_levels:
           return "marginally distinguished"
        elif "uncertain" in evidence_levels:
            return "uncertain"
        elif "not observed" in evidence_levels:
            return "not observed"

    else:
        if "not observed" in evidence_levels:
            return "not observed"
        elif "uncertain" in evidence_levels:
            return "uncertain"
        elif "marginally_distinguished" in evidence_levels:
            return "marginally distinguished"
        elif "indistinguishable_from_canonical" in evidence_levels:
            return "indistinguishable from canonical"
        elif "canonical" in evidence_levels:
            return "canonical"

    return evidence_levels

# %%
def plot_cluster(threshold, min_proteins = 1, min_degree = 1000, show_counts = False, use_highest_evidence_level = True):
    filename = "../search_proteome/cd-hit/clusterings/cdhit_stains_prefixed_cdhit_c{}.fasta.clstr".format(threshold)
    df = parse_clstr_file(filename)#, identified_proteins = IDs[classification]["biosequence_name"].tolist())
    df["evidence_levels"] = df.apply(lambda x: retrieve_highest_evidence_level(x, use_highest_evidence_level), axis=1)

    # replace every protein with "True" and every 0 with "False"
    df = df.drop(columns=["cluster"])
    for strain in strains:
        df[strain] = df[strain].apply(lambda x: True if x != 0 else False)

    # turn to multiindex
    df2 = df.set_index(strains)

    df2["evidence_levels"] = pd.Categorical(df2["evidence_levels"], categories=["canonical", "indistinguishable from canonical", "marginally distinguished", "uncertain", "not observed"])
    df2 = df2.sort_values(by="evidence_levels")

    upset = UpSet(df2, intersection_plot_elements=0, min_subset_size=min_proteins, min_degree=min_degree, show_counts=show_counts)  # disable the default bar chart
    upset.add_stacked_bars(
        by="evidence_levels", title="Proteoforms by evidence level", elements=10, colors={"canonical": "#2ca02c", "indistinguishable from canonical": "#974EA4", "marginally distinguished": "#ff7f0e", "uncertain": "#1f77b4", "not observed": "#D62628"}
    )
    upset.plot()

    return

# %%
plot_cluster(".99", min_proteins = 100, min_degree = 1, show_counts=False, use_highest_evidence_level=True)
# Out:
# evidence_levels
# not observed                        5182
# canonical                           4670
# uncertain                           4607
# marginally distinguished            1121
# indistinguishable from canonical     293
# Name: count, dtype: int64

# %%
plot_cluster(".99", min_proteins = 100, min_degree = 1, show_counts=False, use_highest_evidence_level=False)
# Out:
# evidence_levels
# uncertain                           6989
# not observed                        5243
# canonical                           1663
# marginally distinguished            1110
# indistinguishable from canonical     868
# Name: count, dtype: int64

# %%
plot_cluster(".95", min_proteins = 100, min_degree = 1, show_counts=False)
# Out:
# evidence_levels
# canonical                           4172
# not observed                        4030
# uncertain                           1523
# marginally distinguished             271
# indistinguishable from canonical      33
# Name: count, dtype: int64

# %%
plot_cluster(".90", min_proteins = 100, min_degree = 1, show_counts=False)
# Out:
# evidence_levels
# canonical                           4128
# not observed                        3719
# uncertain                           1146
# marginally distinguished             216
# indistinguishable from canonical      14
# Name: count, dtype: int64

# %%
plot_cluster(".99", min_proteins = 50, min_degree = 1, show_counts=False)
# Out:
# evidence_levels
# not observed                        5182
# canonical                           4670
# uncertain                           4607
# marginally distinguished            1121
# indistinguishable from canonical     293
# Name: count, dtype: int64

# %%
plot_cluster("1.00", min_proteins = 100, min_degree = 1, show_counts=False)

# %%
plot_cluster("1.00", min_proteins = 100, min_degree = 1, show_counts=False, use_highest_evidence_level=False)

# %%
plot_cluster(".70", min_proteins = 100, min_degree = 1, show_counts=False)
# Out:
# evidence_levels
# canonical                           4055
# not observed                        3279
# uncertain                            807
# marginally distinguished             165
# indistinguishable from canonical       4
# Name: count, dtype: int64

# %%
plot_cluster(".70", min_proteins = 100, min_degree = 1, show_counts=False, use_highest_evidence_level=False)

# %%
plot_cluster("1.00", min_proteins = 20, min_degree = 10, show_counts=False)
# Out:
# evidence_levels
# uncertain                           10485
# not observed                         6141
# canonical                            5368
# marginally distinguished             2736
# indistinguishable from canonical     1312
# Name: count, dtype: int64
